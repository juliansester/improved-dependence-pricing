# %% [markdown]
# # Price bound examples

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d, Axes3D
from MOT_2dim2assets import *
from MOT_dual_2dim2assets import *
from MOT_ndim import *
from Multidim_useful_functions import *
from matplotlib import rc
from matplotlib import style
from matplotlib.ticker import (AutoMinorLocator, MultipleLocator)
style.use('ggplot')

print("Necessary Packages imported")
# Out:
# Necessary Packages imported

# %% [markdown]
# ### Example 5.7 and Table 3

# %%
# First Security
p11 = np.repeat(1/3,3)
v11 = [8,10,12]
p21 = np.repeat(1/4,4)
v21 = [7,9,11,13]
# Second Security
p12 = np.repeat(1/3,3)
v12 = [8,10,12]
p22 = np.repeat(1/5,5)
v22 = [4,7,10,13,16]

def payoff1(a,b,c,d):
    return max((1/4)*(a+b+c+d)-10,0)

def payoff2(a,b,c,d):
    return max(10-min([a,b,c,d]),0)
    #return (c>a)*(d>b)

def payoff3(a,b,c,d):
    return (1/4)*max(b-a,0)*max(d-c,0)

def payoff4(a,b,c,d):
    return ((c-a)/a)**2*((d-b)/b)**2

def payoff5(a,b,c,d):
    return max(((c-a)/a)*((d-b)/b),0)

## First Row of Table
m11 = (opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,func=payoff1,onedim=True,minimize=True,schmithals=True)[0])
m12 = (opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,func=payoff1,onedim=True,minimize=True)[0])
m13 = (opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,func=payoff1,onedim=True,minimize=False)[0])
m14 = (opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,func=payoff1,onedim=True,minimize=False,schmithals=True)[0])
m11=round(m11,4)
m12=round(m12,4)
m13=round(m13,4)
m14=round(m14,4)
table_text = "Example 2.2 \n ------------ \n" + "{m11} | {m12} | {m13} | {m14} \n"

## First Row of Table
m21 = (opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,func=payoff2,onedim=True,minimize=True,schmithals=True)[0])
m22 = (opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,func=payoff2,onedim=True,minimize=True)[0])
m23 = (opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,func=payoff2,onedim=True,minimize=False)[0])
m24 = (opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,func=payoff2,onedim=True,minimize=False,schmithals=True)[0])
m21=round(m21,4)
m22=round(m22,4)
m23=round(m23,4)
m24=round(m24,4)
table_text = table_text+"{m21} | {m22} | {m23} | {m24} \n"

## First Row of Table
m31 = (opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,func=payoff3,onedim=True,minimize=True,schmithals=True)[0])
m32 = (opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,func=payoff3,onedim=True,minimize=True)[0])
m33 = (opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,func=payoff3,onedim=True,minimize=False)[0])
m34 = (opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,func=payoff3,onedim=True,minimize=False,schmithals=True)[0])
m31=round(m31,4)
m32=round(m32,4)
m33=round(m33,4)
m34=round(m34,4)
table_text = table_text+"{m31} | {m32} | {m33} | {m34} \n"

## First Row of Table
m41 = (opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,func=payoff4,onedim=True,minimize=True,schmithals=True)[0])
m42 = (opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,func=payoff4,onedim=True,minimize=True)[0])
m43 = (opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,func=payoff4,onedim=True,minimize=False)[0])
m44 = (opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,func=payoff4,onedim=True,minimize=False,schmithals=True)[0])
m41=round(m41,4)
m42=round(m42,4)
m43=round(m43,4)
m44=round(m44,4)
table_text = table_text+"{m41} | {m42} | {m43} | {m44} \n"

## First Row of Table
m51 = (opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,func=payoff5,onedim=True,minimize=True,schmithals=True)[0])
m52 = (opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,func=payoff5,onedim=True,minimize=True)[0])
m53 = (opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,func=payoff5,onedim=True,minimize=False)[0])
m54 = (opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,func=payoff5,onedim=True,minimize=False,schmithals=True)[0])
m51=round(m51,4)
m52=round(m52,4)
m53=round(m53,4)
m54=round(m54,4)
table_text = table_text+"{m51} | {m52} | {m53} | {m54} \n"

print(table_text.format(m11 =m11,m12 =m12,m13=m13,m14=m14,m21=m21,m22=m22,m23=m23,m24=m24,m31=m31,m32=m32,m33=m33,
                        m34=m34,m41=m41,m42=m42,m43=m43,m44=m44,m51=m51,m52=m52,m53=m53,m54=m54))
# Out:
# Using license file c:\gurobi\gurobi.lic
# Academic license - for non-commercial use only
# Example 2.2
#  ------------
# 0.1464 | 0.25 | 1.0111 | 1.0222
# 1.9611 | 1.9611 | 3.2167 | 3.25
# 0.0 | 0.0 | 1.9778 | 2.1222
# 0.001 | 0.0012 | 0.0207 | 0.0218
# 0.0 | 0.0 | 0.0687 | 0.072

# %% [markdown]
# ### Example 5.8. Correlation Improvement, Figure 6(a)

# %%
### Correlation improvement

#Figure 1
# Nr. of Discretization Points
N = 100
"""
lower_bound_1_old = opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,func=payoff1,onedim=True,minimize=True)[0]
upper_bound_1_old = opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,func=payoff1,onedim=True,minimize=False)[0]
lower_bound_2_old = opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,func=payoff2,onedim=True,minimize=True)[0]
upper_bound_2_old = opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,func=payoff2,onedim=True,minimize=False)[0]
lower_bound_3_old = opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,func=payoff3,onedim=True,minimize=True)[0]
upper_bound_3_old = opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,func=payoff3,onedim=True,minimize=False)[0]
lower_bound_4_old = opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,func=payoff4,onedim=True,minimize=True)[0]
upper_bound_4_old = opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,func=payoff4,onedim=True,minimize=False)[0]
lower_bound_5_old = opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,func=payoff5,onedim=True,minimize=True)[0]
upper_bound_5_old = opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,func=payoff5,onedim=True,minimize=False)[0]
"""
lower_bound1 = []
upper_bound1 = []
lower_bound2 = []
upper_bound2 = []
lower_bound3 = []
upper_bound3 = []
lower_bound4 = []
upper_bound4 = []
lower_bound5 = []
upper_bound5 = []
corr = np.linspace(-1,1,N)
lb1 = opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,func=payoff1,onedim=True,minimize=True)[0]
ub1 = opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,func=payoff1,onedim=True,minimize=False)[0]
lb2 = opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,func=payoff2,onedim=True,minimize=True)[0]
ub2 = opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,func=payoff2,onedim=True,minimize=False)[0]
lb3 = opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,func=payoff3,onedim=True,minimize=True)[0]
ub3 = opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,func=payoff3,onedim=True,minimize=False)[0]
lb4 = opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,func=payoff4,onedim=True,minimize=True)[0]
ub4 = opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,func=payoff4,onedim=True,minimize=False)[0]

for i in range(N):
    lower_bound1.append(opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,
                                                     func=payoff1,onedim=True,minimize=True,correlation_1=True,corr_1=corr[i])[0])
    upper_bound1.append(opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,
                                                     func=payoff1,onedim=True,minimize=False,correlation_1=True,corr_1=corr[i])[0])
    lower_bound2.append(opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,
                                                     func=payoff2,onedim=True,minimize=True,correlation_1=True,corr_1=corr[i])[0])
    upper_bound2.append(opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,
                                                     func=payoff2,onedim=True,minimize=False,correlation_1=True,corr_1=corr[i])[0])
    lower_bound3.append(opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,
                                                     func=payoff3,onedim=True,minimize=True,correlation_1=True,corr_1=corr[i])[0])
    upper_bound3.append(opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,
                                                     func=payoff3,onedim=True,minimize=False,correlation_1=True,corr_1=corr[i])[0])
    lower_bound4.append(opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,
                                                     func=payoff4,onedim=True,minimize=True,correlation_1=True,corr_1=corr[i])[0])
    upper_bound4.append(opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,
                                                     func=payoff4,onedim=True,minimize=False,correlation_1=True,corr_1=corr[i])[0])
    lower_bound5.append(opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,
                                                     func=payoff5,onedim=True,minimize=True,correlation_1=True,corr_1=corr[i])[0])
    upper_bound5.append(opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,
                                                     func=payoff5,onedim=True,minimize=False,correlation_1=True,corr_1=corr[i])[0])

# %%
fig, axs = plt.subplots(2, 2)
axs[0, 0].plot(corr, lower_bound1,color="blue")
axs[0, 0].plot(corr, upper_bound1,color="red")
axs[0, 0].plot(corr, np.repeat(lb1,N), color="blue",linestyle = "--")
axs[0, 0].plot(corr, np.repeat(ub1,N),color="red",linestyle = "--")
axs[0, 0].set_title(r'$c_4$')
axs[0, 0].set_xticklabels([])
axs[0, 0].set_xticks([-1,-0.5,0,0.5,1])
#axs[0, 0].set_yticks([0.25,0.5,0.75,1])
axs[0, 0].fill_between(corr, lower_bound1, np.repeat(lb1,N), color='aliceblue')
axs[0, 0].fill_between(corr, upper_bound1, np.repeat(ub1,N), color='mistyrose')
axs[0, 1].plot(corr, lower_bound2,color="blue")
axs[0, 1].plot(corr, upper_bound2,color="red")
axs[0, 1].plot(corr, np.repeat(lb2,N), color="blue",linestyle = "--")
axs[0, 1].plot(corr, np.repeat(ub2,N),color="red",linestyle = "--")
axs[0, 1].set_title(r'$c_5$')
axs[0, 1].set_xticklabels([])
axs[0, 1].set_xticks([-1,-0.5,0,0.5,1])
#axs[0, 1].set_yticks([0,0.2,0.4,0.6])
axs[0, 1].fill_between(corr, lower_bound2, np.repeat(lb2,N), color='aliceblue')
axs[0, 1].fill_between(corr, upper_bound2, np.repeat(ub2,N), color='mistyrose')
axs[1, 0].plot(corr, lower_bound3,color="blue")
axs[1, 0].plot(corr, upper_bound3,color="red")
axs[1, 0].plot(corr, np.repeat(lb3,N), color="blue",linestyle = "--")
axs[1, 0].plot(corr, np.repeat(ub3,N),color="red",linestyle = "--")
axs[1, 0].set_title(r'$c_6$')
axs[1, 0].set_xticks([-1,-0.5,0,0.5,1])
#axs[1, 0].set_yticks([0,0.5])
axs[1, 0].fill_between(corr, lower_bound3, np.repeat(lb3,N), color='aliceblue')
axs[1, 0].fill_between(corr, upper_bound3, np.repeat(ub3,N), color='mistyrose')
axs[1, 1].plot(corr, lower_bound4,color="blue")
axs[1, 1].plot(corr, upper_bound4,color="red")
axs[1, 1].plot(corr, np.repeat(lb4,N), color="blue",linestyle = "--")
axs[1, 1].plot(corr, np.repeat(ub4,N),color="red",linestyle = "--")
axs[1, 1].set_title(r'$c_7$')
axs[1, 1].set_xticks([-1,-0.5,0,0.5,1])
#axs[1, 1].set_yticks([0.01,0.02])
axs[1, 1].fill_between(corr, lower_bound4, np.repeat(lb4,N), color='aliceblue')
axs[1, 1].fill_between(corr, upper_bound4, np.repeat(ub4,N), color='mistyrose')
axs[0, 0].set(ylabel='Price Bounds')
axs[1, 0].set(xlabel='Correlation', ylabel='Price Bounds')
axs[1, 1].set(xlabel='Correlation')
axs[0,0].grid(True, linestyle='--')
axs[0,1].grid(True, linestyle='--')
axs[1,0].grid(True, linestyle='--')
axs[1,1].grid(True, linestyle='--')
plt.savefig('fig_correlations_improvement_1.eps', format='eps')
plt.show()

# %% [markdown]
# ### Example 5.8. Correlation Improvement, Figure 6(b)

# %%
# Figure 2

N = 100
lower_bound_1_old = opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,func=payoff1,onedim=True,minimize=True)[0]
upper_bound_1_old = opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,func=payoff1,onedim=True,minimize=False)[0]
lower_bound_2_old = opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,func=payoff2,onedim=True,minimize=True)[0]
upper_bound_2_old = opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,func=payoff2,onedim=True,minimize=False)[0]
lower_bound_3_old = opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,func=payoff3,onedim=True,minimize=True)[0]
upper_bound_3_old = opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,func=payoff3,onedim=True,minimize=False)[0]
lower_bound_4_old = opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,func=payoff4,onedim=True,minimize=True)[0]
upper_bound_4_old = opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,func=payoff4,onedim=True,minimize=False)[0]
lower_bound_5_old = opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,func=payoff5,onedim=True,minimize=True)[0]
upper_bound_5_old = opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,func=payoff5,onedim=True,minimize=False)[0]

lower_bound1 = []
upper_bound1 = []
lower_bound2 = []
upper_bound2 = []
lower_bound3 = []
upper_bound3 = []
lower_bound4 = []
upper_bound4 = []
lower_bound5 = []
upper_bound5 = []
corr = np.linspace(-0.8713832,0.8713832,N)


for i in range(N):
    lower_bound1.append(opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,
                                                     func=payoff1,onedim=True,minimize=True,correlation_2=True,corr_2=corr[i])[0])
    upper_bound1.append(opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,
                                                     func=payoff1,onedim=True,minimize=False,correlation_2=True,corr_2=corr[i])[0])
    lower_bound2.append(opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,
                                                     func=payoff2,onedim=True,minimize=True,correlation_2=True,corr_2=corr[i])[0])
    upper_bound2.append(opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,
                                                     func=payoff2,onedim=True,minimize=False,correlation_2=True,corr_2=corr[i])[0])
    lower_bound3.append(opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,
                                                     func=payoff3,onedim=True,minimize=True,correlation_2=True,corr_2=corr[i])[0])
    upper_bound3.append(opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,
                                                     func=payoff3,onedim=True,minimize=False,correlation_2=True,corr_2=corr[i])[0])
    lower_bound4.append(opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,
                                                     func=payoff4,onedim=True,minimize=True,correlation_2=True,corr_2=corr[i])[0])
    upper_bound4.append(opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,
                                                     func=payoff4,onedim=True,minimize=False,correlation_2=True,corr_2=corr[i])[0])
    lower_bound5.append(opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,
                                                     func=payoff5,onedim=True,minimize=True,correlation_2=True,corr_2=corr[i])[0])
    upper_bound5.append(opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,
                                                     func=payoff5,onedim=True,minimize=False,correlation_2=True,corr_2=corr[i])[0])

# %%
fig, axs = plt.subplots(2, 2)
axs[0, 0].plot(corr, lower_bound1,color="blue")
axs[0, 0].plot(corr, upper_bound1,color="red")
axs[0, 0].plot(corr, np.repeat(lb1,N), color="blue",linestyle = "--")
axs[0, 0].plot(corr, np.repeat(ub1,N),color="red",linestyle = "--")
axs[0, 0].set_title(r'$c_4$')
axs[0, 0].set_xticklabels([])
axs[0, 0].set_xticks([-1,-0.5,0,0.5,1])
#axs[0, 0].set_yticks([0.25,0.5,0.75,1])
axs[0, 0].fill_between(corr, lower_bound1, np.repeat(lb1,N), color='aliceblue')
axs[0, 0].fill_between(corr, upper_bound1, np.repeat(ub1,N), color='mistyrose')
axs[0, 1].plot(corr, lower_bound2,color="blue")
axs[0, 1].plot(corr, upper_bound2,color="red")
axs[0, 1].plot(corr, np.repeat(lb2,N), color="blue",linestyle = "--")
axs[0, 1].plot(corr, np.repeat(ub2,N),color="red",linestyle = "--")
axs[0, 1].set_title(r'$c_5$')
axs[0, 1].set_xticklabels([])
axs[0, 1].set_xticks([-1,-0.5,0,0.5,1])
#axs[0, 1].set_yticks([0,0.2,0.4,0.6])
axs[0, 1].fill_between(corr, lower_bound2, np.repeat(lb2,N), color='aliceblue')
axs[0, 1].fill_between(corr, upper_bound2, np.repeat(ub2,N), color='mistyrose')
axs[1, 0].plot(corr, lower_bound3,color="blue")
axs[1, 0].plot(corr, upper_bound3,color="red")
axs[1, 0].plot(corr, np.repeat(lb3,N), color="blue",linestyle = "--")
axs[1, 0].plot(corr, np.repeat(ub3,N),color="red",linestyle = "--")
axs[1, 0].set_title(r'$c_6$')
axs[1, 0].set_xticks([-1,-0.5,0,0.5,1])
#axs[1, 0].set_yticks([0,0.5])
axs[1, 0].fill_between(corr, lower_bound3, np.repeat(lb3,N), color='aliceblue')
axs[1, 0].fill_between(corr, upper_bound3, np.repeat(ub3,N), color='mistyrose')
axs[1, 1].plot(corr, lower_bound4,color="blue")
axs[1, 1].plot(corr, upper_bound4,color="red")
axs[1, 1].plot(corr, np.repeat(lb4,N), color="blue",linestyle = "--")
axs[1, 1].plot(corr, np.repeat(ub4,N),color="red",linestyle = "--")
axs[1, 1].set_title(r'$c_7$')
axs[1, 1].set_xticks([-1,-0.5,0,0.5,1])
#axs[1, 1].set_yticks([0.01,0.02])
axs[1, 1].fill_between(corr, lower_bound4, np.repeat(lb4,N), color='aliceblue')
axs[1, 1].fill_between(corr, upper_bound4, np.repeat(ub4,N), color='mistyrose')
axs[0, 0].set(ylabel='Price Bounds')
axs[1, 0].set(xlabel='Correlation', ylabel='Price Bounds')
axs[1, 1].set(xlabel='Correlation')
axs[0,0].grid(True, linestyle='--')
axs[0,1].grid(True, linestyle='--')
axs[1,0].grid(True, linestyle='--')
axs[1,1].grid(True, linestyle='--')
plt.savefig('fig_correlations_improvement_2.eps', format='eps')
plt.show()

# %% [markdown]
# ### Example 5.8, Figure 7

# %%
### Calculations.

N = 25
N2 = 5
corr1 = np.linspace(-0.25,0.25,N)
corr2 = np.linspace(0.25,-0.25,N)
corr1_wo = np.linspace(-0.25,0.25,N2)
corr2_wo = np.linspace(0.25,-0.25,N2)
lower_bound_matrix_1 = np.zeros((N,N))
upper_bound_matrix_1 = np.zeros((N,N))
lower_bound_matrix_2 = np.zeros((N,N))
upper_bound_matrix_2 = np.zeros((N,N))
lower_bound_matrix_3 = np.zeros((N,N))
upper_bound_matrix_3 = np.zeros((N,N))
lower_bound_matrix_4 = np.zeros((N,N))
upper_bound_matrix_4 = np.zeros((N,N))
lower_bound_without_corr_1 = np.zeros((N2,N2))
upper_bound_without_corr_1 = np.zeros((N2,N2))
lower_bound_without_corr_2 = np.zeros((N2,N2))
upper_bound_without_corr_2 = np.zeros((N2,N2))
lower_bound_without_corr_3 = np.zeros((N2,N2))
upper_bound_without_corr_3 = np.zeros((N2,N2))
lower_bound_without_corr_4 = np.zeros((N2,N2))
upper_bound_without_corr_4 = np.zeros((N2,N2))
lb1 = opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,func=payoff1,onedim=True,minimize=True)[0]
ub1 = opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,func=payoff1,onedim=True,minimize=False)[0]
lb2 = opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,func=payoff2,onedim=True,minimize=True)[0]
ub2 = opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,func=payoff2,onedim=True,minimize=False)[0]
lb3 = opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,func=payoff3,onedim=True,minimize=True)[0]
ub3 = opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,func=payoff3,onedim=True,minimize=False)[0]
lb4 = opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,func=payoff4,onedim=True,minimize=True)[0]
ub4 = opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,func=payoff4,onedim=True,minimize=False)[0]

for i in range(N):
    for j in range(N):
        lower_bound_matrix_1[i,j] = opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,
                                                     func=payoff1,onedim=True,minimize=True,
                                                     correlation_1=True,corr_1=corr1[i],correlation_2=True,corr_2=corr2[j])[0]
        upper_bound_matrix_1[i,j] = opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,
                                                     func=payoff1,onedim=True,minimize=False,
                                                     correlation_1=True,corr_1=corr1[i],correlation_2=True,corr_2=corr2[j])[0]
        lower_bound_matrix_2[i,j] = opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,
                                                     func=payoff2,onedim=True,minimize=True,
                                                     correlation_1=True,corr_1=corr1[i],correlation_2=True,corr_2=corr2[j])[0]
        upper_bound_matrix_2[i,j] = opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,
                                                     func=payoff2,onedim=True,minimize=False,
                                                     correlation_1=True,corr_1=corr1[i],correlation_2=True,corr_2=corr2[j])[0]
        lower_bound_matrix_3[i,j] = opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,
                                                     func=payoff3,onedim=True,minimize=True,
                                                     correlation_1=True,corr_1=corr1[i],correlation_2=True,corr_2=corr2[j])[0]
        upper_bound_matrix_3[i,j] = opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,
                                                     func=payoff3,onedim=True,minimize=False,
                                                     correlation_1=True,corr_1=corr1[i],correlation_2=True,corr_2=corr2[j])[0]
        lower_bound_matrix_4[i,j] = opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,
                                                     func=payoff4,onedim=True,minimize=True,
                                                     correlation_1=True,corr_1=corr1[i],correlation_2=True,corr_2=corr2[j])[0]
        upper_bound_matrix_4[i,j] = opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,
                                                     func=payoff4,onedim=True,minimize=False,
                                                     correlation_1=True,corr_1=corr1[i],correlation_2=True,corr_2=corr2[j])[0]

for i in range(N2):
    for j in range(N2):
        lower_bound_without_corr_1[i,j] = lb1
        upper_bound_without_corr_1[i,j] = ub1
        lower_bound_without_corr_2[i,j] = lb2
        upper_bound_without_corr_2[i,j] = ub2
        lower_bound_without_corr_3[i,j] = lb3
        upper_bound_without_corr_3[i,j] = ub3
        lower_bound_without_corr_4[i,j] = lb4
        upper_bound_without_corr_4[i,j] = ub4

# %% [markdown]
# Next, we plot the results.

# %%
# Plotting       
style.use('default')

fig = plt.figure()
ax = Axes3D(fig)

X, Y = np.meshgrid(corr1, corr2)
X_wo, Y_wo = np.meshgrid(corr1_wo, corr2_wo)
ax.plot_surface(X, Y , lower_bound_matrix_1,color = "cornflowerblue")
ax.plot_wireframe(X_wo, Y_wo , lower_bound_without_corr_1,color = "cornflowerblue")
ax.plot_surface(X, Y , upper_bound_matrix_1,color = "salmon")
ax.plot_wireframe(X_wo, Y_wo, upper_bound_without_corr_1,color = "salmon")
ax.view_init(20, 45)
ax.set_xlabel('Correlation at Time 1')
ax.set_ylabel('Correlation at Time 2')
ax.set_zlabel('Price Bounds for c4');
plt.savefig('fig_3d_correlations_1.eps', format='eps')
plt.show()


#Nr2

fig = plt.figure()
ax = Axes3D(fig)


X, Y = np.meshgrid(corr1, corr2)
X_wo, Y_wo = np.meshgrid(corr1_wo, corr2_wo)
ax.plot_surface(X, Y , lower_bound_matrix_2,color = "cornflowerblue")
ax.plot_wireframe(X_wo, Y_wo , lower_bound_without_corr_2,color = "cornflowerblue")
ax.plot_surface(X, Y , upper_bound_matrix_2,color = "salmon")
ax.plot_wireframe(X_wo, Y_wo, upper_bound_without_corr_2,color = "salmon")
ax.view_init(20, 45)
ax.set_xlabel('Correlation at Time 1')
ax.set_ylabel('Correlation at Time 2')
ax.set_zlabel('Price Bounds for c5');
plt.savefig('fig_3d_correlations_2.eps', format='eps')
plt.show()

#Nr3

fig = plt.figure()
ax = Axes3D(fig)


X, Y = np.meshgrid(corr1, corr2)
X_wo, Y_wo = np.meshgrid(corr1_wo, corr2_wo)
ax.plot_surface(X, Y , lower_bound_matrix_3,color = "cornflowerblue")
ax.plot_wireframe(X_wo, Y_wo , lower_bound_without_corr_3,color = "cornflowerblue")
ax.plot_surface(X, Y , upper_bound_matrix_3,color = "salmon")
ax.plot_wireframe(X_wo, Y_wo, upper_bound_without_corr_3,color = "salmon")
ax.view_init(20, 45)
ax.set_xlabel('Correlation at Time 1')
ax.set_ylabel('Correlation at Time 2')
ax.set_zlabel('Price Bounds for c6');
plt.savefig('fig_3d_correlations_3.eps', format='eps')
plt.show()

#Nr4

fig = plt.figure()
ax = Axes3D(fig)


X, Y = np.meshgrid(corr1, corr2)
X_wo, Y_wo = np.meshgrid(corr1_wo, corr2_wo)
ax.plot_surface(X, Y , lower_bound_matrix_4,color = "cornflowerblue")
ax.plot_wireframe(X_wo, Y_wo , lower_bound_without_corr_4,color = "cornflowerblue")
ax.plot_surface(X, Y , upper_bound_matrix_4,color = "salmon")
ax.plot_wireframe(X_wo, Y_wo, upper_bound_without_corr_4,color = "salmon")
ax.view_init(20, 45)
ax.set_xlabel('Correlation at Time 1')
ax.set_ylabel('Correlation at Time 2')
ax.set_zlabel('Price Bounds for c7');
plt.savefig('fig_3d_correlations_4.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# ...

# %% [markdown]
# ### Example 5.9. Basket Prices vs. Correlations, Figure 8
# Now we want to study the difference between derivation of correlation information and the inclusion of basket option prices.

# %%
N=25
different_Qs = 10
strikes_basket = np.linspace(5,15,100).tolist()

lower_bound1 = []
upper_bound1 = []
lower_bound2 = []
upper_bound2 = []
lower_bound3 = []
upper_bound3 = []
lower_bound4 = []
upper_bound4 = []
lower_bound1_basket = []
upper_bound1_basket = []
lower_bound2_basket = []
upper_bound2_basket = []
lower_bound3_basket = []
upper_bound3_basket = []
lower_bound4_basket = []
upper_bound4_basket = []
# For extremeal Bounds:
lower_bound1_basket_ext = []
upper_bound1_basket_ext = []
lower_bound2_basket_ext = []
upper_bound2_basket_ext = []
lower_bound3_basket_ext = []
upper_bound3_basket_ext = []
lower_bound4_basket_ext = []
upper_bound4_basket_ext = []

corr = np.linspace(-1,1,N)


for i in range(N):
    lower_bound1.append(opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,
                                                     func=payoff1,onedim=True,minimize=True,correlation_1=True,corr_1=corr[i])[0])
    upper_bound1.append(opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,
                                                     func=payoff1,onedim=True,minimize=False,correlation_1=True,corr_1=corr[i])[0])
    lower_bound2.append(opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,
                                                     func=payoff2,onedim=True,minimize=True,correlation_1=True,corr_1=corr[i])[0])
    upper_bound2.append(opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,
                                                     func=payoff2,onedim=True,minimize=False,correlation_1=True,corr_1=corr[i])[0])
    lower_bound3.append(opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,
                                                     func=payoff3,onedim=True,minimize=True,correlation_1=True,corr_1=corr[i])[0])
    upper_bound3.append(opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,
                                                     func=payoff3,onedim=True,minimize=False,correlation_1=True,corr_1=corr[i])[0])
    lower_bound4.append(opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,
                                                     func=payoff4,onedim=True,minimize=True,correlation_1=True,corr_1=corr[i])[0])
    upper_bound4.append(opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,
                                                     func=payoff4,onedim=True,minimize=False,correlation_1=True,corr_1=corr[i])[0])
    prices_b = generate_basket_prices(v11,p11,v12,p12,v21,p21,v22,p22,corr[i],strikes_basket,time = 1,different_Qs= different_Qs)
    l1 = []
    u1 = []
    l2 = []
    u2 = []
    l3 = []
    u3 = []
    l4 = []
    u4 = []
    for j in range(different_Qs):
        l1.append(opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,payoff1,minimize=True,
                              basket_prices = prices_b[j],basket_strikes=strikes_basket,basket_time = 1)[0])
        u1.append(opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,payoff1,minimize=False,
                              basket_prices = prices_b[j],basket_strikes=strikes_basket,basket_time = 1)[0])
        l2.append(opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,payoff2,minimize=True,
                              basket_prices = prices_b[j],basket_strikes=strikes_basket,basket_time = 1)[0])
        u2.append(opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,payoff2,minimize=False,
                              basket_prices = prices_b[j],basket_strikes=strikes_basket,basket_time = 1)[0])
        l3.append(opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,payoff3,minimize=True,
                              basket_prices = prices_b[j],basket_strikes=strikes_basket,basket_time = 1)[0])
        u3.append(opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,payoff3,minimize=False,
                              basket_prices = prices_b[j],basket_strikes=strikes_basket,basket_time = 1)[0])
        l4.append(opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,payoff4,minimize=True,
                              basket_prices = prices_b[j],basket_strikes=strikes_basket,basket_time = 1)[0])
        u4.append(opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,payoff4,minimize=False,
                              basket_prices = prices_b[j],basket_strikes=strikes_basket,basket_time = 1)[0])
    lower_bound1_basket.append(np.mean(l1))
    upper_bound1_basket.append(np.mean(u1))
    lower_bound2_basket.append(np.mean(l2))
    upper_bound2_basket.append(np.mean(u2))
    lower_bound3_basket.append(np.mean(l3))
    upper_bound3_basket.append(np.mean(u3))
    lower_bound4_basket.append(np.mean(l4))
    upper_bound4_basket.append(np.mean(u4))
    lower_bound1_basket_ext.append(np.max(l1))
    upper_bound1_basket_ext.append(np.min(u1))
    lower_bound2_basket_ext.append(np.max(l2))
    upper_bound2_basket_ext.append(np.min(u2))
    lower_bound3_basket_ext.append(np.max(l3))
    upper_bound3_basket_ext.append(np.min(u3))
    lower_bound4_basket_ext.append(np.max(l4))
    upper_bound4_basket_ext.append(np.min(u4))

# %%
style.use('ggplot')

plt.rcParams.update({'font.size': 15})
fig, axs = plt.subplots(2, 2,figsize = [6,5])
axs[0, 0].plot(corr, lower_bound1,color="blue")
axs[0, 0].plot(corr, lower_bound1_basket,color="blue",linestyle='dotted')
axs[0, 0].plot(corr, lower_bound1_basket_ext,color="blue",linestyle='dashed')
axs[0, 0].plot(corr, upper_bound1,color="red")
axs[0, 0].plot(corr, upper_bound1_basket,color="red", linestyle='dotted')
axs[0, 0].plot(corr, upper_bound1_basket_ext,color="red",linestyle='dashed')
axs[0, 0].plot(corr, np.repeat(np.max(upper_bound1),N),color="black",linestyle='dashdot')
axs[0, 0].plot(corr, np.repeat(np.min(lower_bound1),N),color="black",linestyle='dashdot')
axs[0, 0].plot(corr, upper_bound1_basket_ext,color="red",linestyle='dashed')
axs[0, 0].set_title(r'$c_4$')
axs[0, 0].set_xticklabels([])
axs[0, 0].set_xticks([-1,-0.5,0,0.5,1])
axs[0, 0].set_yticks([0.25,0.5,0.75,1])
axs[0, 0].fill_between(corr, lower_bound1, lower_bound1_basket, color='aliceblue')
axs[0, 0].fill_between(corr, upper_bound1, upper_bound1_basket, color='mistyrose')
axs[0, 1].plot(corr, upper_bound2,color="red")
axs[0, 1].plot(corr, upper_bound2_basket,color="red", linestyle='dotted')
axs[0, 1].plot(corr, upper_bound2_basket_ext,color="red",linestyle='dashed')
axs[0, 1].plot(corr, lower_bound2_basket,color="blue", linestyle='dotted')
axs[0, 1].plot(corr, lower_bound2_basket_ext,color="blue",linestyle='dashed')
axs[0, 1].plot(corr, lower_bound2,color="blue")
axs[0, 1].plot(corr, np.repeat(np.max(upper_bound2),N),color="black",linestyle='dashdot')
axs[0, 1].plot(corr, np.repeat(np.min(lower_bound2),N),color="black",linestyle='dashdot')
axs[0, 1].set_title(r'$c_5$')
axs[0, 1].set_xticklabels([])
axs[0, 1].set_xticks([-1,-0.5,0,0.5,1])
#axs[0, 1].set_yticks([0,0.2,0.4,0.6])
axs[0, 1].fill_between(corr, lower_bound2, lower_bound2_basket, color='aliceblue')
axs[0, 1].fill_between(corr, upper_bound2, upper_bound2_basket, color='mistyrose')
axs[1, 0].plot(corr, lower_bound3,color="blue")
axs[1, 0].plot(corr, upper_bound3,color="red")
axs[1, 0].plot(corr, lower_bound3_basket,color="blue", linestyle='dotted')
axs[1, 0].plot(corr, lower_bound3_basket_ext,color="blue",linestyle='dashed')
axs[1, 0].plot(corr, upper_bound3_basket,color="red", linestyle='dotted')
axs[1, 0].plot(corr, upper_bound3_basket_ext,color="red",linestyle='dashed')
axs[1, 0].plot(corr, np.repeat(np.max(upper_bound3),N),color="black",linestyle='dashdot')
axs[1, 0].plot(corr, np.repeat(np.min(lower_bound3),N),color="black",linestyle='dashdot')
axs[1, 0].set_title(r'$c_6$')
axs[1, 0].set_xticks([-1,-0.5,0,0.5,1])
#axs[1, 0].set_yticks([0,0.5])
axs[1, 0].fill_between(corr, lower_bound3, lower_bound3_basket, color='aliceblue')
axs[1, 0].fill_between(corr, upper_bound3, upper_bound3_basket, color='mistyrose')
axs[1, 1].plot(corr, upper_bound4,color="red",label = "Correlations, Upper Bound")
axs[1, 1].plot(corr, upper_bound4_basket,color="red", linestyle='dotted',label = "Basket Prices, Avg. Upper Bound")
axs[1, 1].plot(corr, upper_bound4_basket_ext,color="red",linestyle='dashed',label = "Basket Prices, Min. Upper Bound")
axs[1, 1].plot(corr, lower_bound4_basket,color="blue", linestyle='dotted',label = "Basket Prices, Avg. Lower Bound")
axs[1, 1].plot(corr, lower_bound4_basket_ext,color="blue",linestyle='dashed',label = "Basket Prices, Max. Lower Bound")
axs[1, 1].plot(corr, lower_bound4,color="blue",label = "Correlations, Lower Bound")
axs[1, 1].plot(corr, np.repeat(np.max(upper_bound4),N),color="black",linestyle='dashdot',label = "Unconstrained Price Bounds")
axs[1, 1].plot(corr, np.repeat(np.min(lower_bound4),N),color="black",linestyle='dashdot')
axs[1, 1].set_title(r'$c_7$')
axs[1, 1].set_xticks([-1,-0.5,0,0.5,1])
#axs[1, 1].set_yticks([0.01,0.02])
axs[1, 1].fill_between(corr, lower_bound4, lower_bound4_basket, color='aliceblue')
axs[1, 1].fill_between(corr, upper_bound4, upper_bound4_basket, color='mistyrose')
axs[0, 0].set(ylabel='Price Bounds')
axs[1, 0].set(xlabel='Correlation', ylabel='Price Bounds')
axs[1, 1].set(xlabel='Correlation')
axs[0,0].grid(True, linestyle='--')
axs[0,1].grid(True, linestyle='--')
axs[1,0].grid(True, linestyle='--')
axs[1,1].grid(True, linestyle='--')

fig.tight_layout()
fig.subplots_adjust(right=1,wspace = 0.25)
plt.savefig('fig_correlations_improvement_loss_time1.eps',format='eps')
plt.show()

# %%
figsize = (4.5, 2.5)
fig_leg = plt.figure(figsize=figsize)
ax_leg = fig_leg.add_subplot(111)
# add the legend from the previous axes
ax_leg.legend(*axs[1,1].get_legend_handles_labels(), loc='center')
# hide the axes frame and the x/y labels
ax_leg.axis('off')
fig_leg.tight_layout()
fig_leg.savefig('fig_correlations_improvement_loss_time1_legend.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# Same Considerations for time 2

# %%
N=25
different_Qs = 10
strikes_basket = np.linspace(5,15,100).tolist()

lower_bound1 = []
upper_bound1 = []
lower_bound2 = []
upper_bound2 = []
lower_bound3 = []
upper_bound3 = []
lower_bound4 = []
upper_bound4 = []
lower_bound1_basket = []
upper_bound1_basket = []
lower_bound2_basket = []
upper_bound2_basket = []
lower_bound3_basket = []
upper_bound3_basket = []
lower_bound4_basket = []
upper_bound4_basket = []

# For extremeal Bounds:
lower_bound1_basket_ext = []
upper_bound1_basket_ext = []
lower_bound2_basket_ext = []
upper_bound2_basket_ext = []
lower_bound3_basket_ext = []
upper_bound3_basket_ext = []
lower_bound4_basket_ext = []
upper_bound4_basket_ext = []

corr = np.linspace(-0.8713832,0.8713832,N)


for i in range(N):
    lower_bound1.append(opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,
                                                     func=payoff1,onedim=True,minimize=True,correlation_2=True,corr_2=corr[i])[0])
    upper_bound1.append(opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,
                                                     func=payoff1,onedim=True,minimize=False,correlation_2=True,corr_2=corr[i])[0])
    lower_bound2.append(opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,
                                                     func=payoff2,onedim=True,minimize=True,correlation_2=True,corr_2=corr[i])[0])
    upper_bound2.append(opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,
                                                     func=payoff2,onedim=True,minimize=False,correlation_2=True,corr_2=corr[i])[0])
    lower_bound3.append(opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,
                                                     func=payoff3,onedim=True,minimize=True,correlation_2=True,corr_2=corr[i])[0])
    upper_bound3.append(opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,
                                                     func=payoff3,onedim=True,minimize=False,correlation_2=True,corr_2=corr[i])[0])
    lower_bound4.append(opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,
                                                     func=payoff4,onedim=True,minimize=True,correlation_2=True,corr_2=corr[i])[0])
    upper_bound4.append(opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,
                                                     func=payoff4,onedim=True,minimize=False,correlation_2=True,corr_2=corr[i])[0])
    prices_b = generate_basket_prices(v11,p11,v12,p12,v21,p21,v22,p22,corr[i],strikes_basket,time = 2,different_Qs= different_Qs)
    l1 = []
    u1 = []
    l2 = []
    u2 = []
    l3 = []
    u3 = []
    l4 = []
    u4 = []
    for j in range(different_Qs):
        l1.append(opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,payoff1,minimize=True,
                              basket_prices = prices_b[j],basket_strikes=strikes_basket,basket_time = 2)[0])
        u1.append(opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,payoff1,minimize=False,
                              basket_prices = prices_b[j],basket_strikes=strikes_basket,basket_time = 2)[0])
        l2.append(opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,payoff2,minimize=True,
                              basket_prices = prices_b[j],basket_strikes=strikes_basket,basket_time = 2)[0])
        u2.append(opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,payoff2,minimize=False,
                              basket_prices = prices_b[j],basket_strikes=strikes_basket,basket_time = 2)[0])
        l3.append(opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,payoff3,minimize=True,
                              basket_prices = prices_b[j],basket_strikes=strikes_basket,basket_time = 2)[0])
        u3.append(opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,payoff3,minimize=False,
                              basket_prices = prices_b[j],basket_strikes=strikes_basket,basket_time = 2)[0])
        l4.append(opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,payoff4,minimize=True,
                              basket_prices = prices_b[j],basket_strikes=strikes_basket,basket_time = 2)[0])
        u4.append(opt_plan_discrete_multiasset(v11,p11,v12,p12,v21,p21,v22,p22,payoff4,minimize=False,
                              basket_prices = prices_b[j],basket_strikes=strikes_basket,basket_time = 2)[0])
    lower_bound1_basket.append(np.mean(l1))
    upper_bound1_basket.append(np.mean(u1))
    lower_bound2_basket.append(np.mean(l2))
    upper_bound2_basket.append(np.mean(u2))
    lower_bound3_basket.append(np.mean(l3))
    upper_bound3_basket.append(np.mean(u3))
    lower_bound4_basket.append(np.mean(l4))
    upper_bound4_basket.append(np.mean(u4))
    lower_bound1_basket_ext.append(np.max(l1))
    upper_bound1_basket_ext.append(np.min(u1))
    lower_bound2_basket_ext.append(np.max(l2))
    upper_bound2_basket_ext.append(np.min(u2))
    lower_bound3_basket_ext.append(np.max(l3))
    upper_bound3_basket_ext.append(np.min(u3))
    lower_bound4_basket_ext.append(np.max(l4))
    upper_bound4_basket_ext.append(np.min(u4))

# %%
style.use('ggplot')

plt.rcParams.update({'font.size': 15})
fig, axs = plt.subplots(2, 2,figsize = [6,5])
axs[0, 0].plot(corr, lower_bound1,color="blue")
axs[0, 0].plot(corr, lower_bound1_basket,color="blue",linestyle='dotted')
axs[0, 0].plot(corr, lower_bound1_basket_ext,color="blue",linestyle='dashed')
axs[0, 0].plot(corr, upper_bound1,color="red")
axs[0, 0].plot(corr, upper_bound1_basket,color="red", linestyle='dotted')
axs[0, 0].plot(corr, upper_bound1_basket_ext,color="red",linestyle='dashed')
axs[0, 0].plot(corr, np.repeat(np.max(upper_bound1),N),color="black",linestyle='dashdot')
axs[0, 0].plot(corr, np.repeat(np.min(lower_bound1),N),color="black",linestyle='dashdot')
axs[0, 0].plot(corr, upper_bound1_basket_ext,color="red",linestyle='dashed')
axs[0, 0].set_title(r'$c_4$')
axs[0, 0].set_xticklabels([])
axs[0, 0].set_xticks([-1,-0.5,0,0.5,1])
axs[0, 0].set_yticks([0.25,0.5,0.75,1])
axs[0, 0].fill_between(corr, lower_bound1, lower_bound1_basket, color='aliceblue')
axs[0, 0].fill_between(corr, upper_bound1, upper_bound1_basket, color='mistyrose')
axs[0, 1].plot(corr, upper_bound2,color="red")
axs[0, 1].plot(corr, upper_bound2_basket,color="red", linestyle='dotted')
axs[0, 1].plot(corr, upper_bound2_basket_ext,color="red",linestyle='dashed')
axs[0, 1].plot(corr, lower_bound2_basket,color="blue", linestyle='dotted')
axs[0, 1].plot(corr, lower_bound2_basket_ext,color="blue",linestyle='dashed')
axs[0, 1].plot(corr, lower_bound2,color="blue")
axs[0, 1].plot(corr, np.repeat(np.max(upper_bound2),N),color="black",linestyle='dashdot')
axs[0, 1].plot(corr, np.repeat(np.min(lower_bound2),N),color="black",linestyle='dashdot')
axs[0, 1].set_title(r'$c_5$')
axs[0, 1].set_xticklabels([])
axs[0, 1].set_xticks([-1,-0.5,0,0.5,1])
#axs[0, 1].set_yticks([0,0.2,0.4,0.6])
axs[0, 1].fill_between(corr, lower_bound2, lower_bound2_basket, color='aliceblue')
axs[0, 1].fill_between(corr, upper_bound2, upper_bound2_basket, color='mistyrose')
axs[1, 0].plot(corr, lower_bound3,color="blue")
axs[1, 0].plot(corr, upper_bound3,color="red")
axs[1, 0].plot(corr, lower_bound3_basket,color="blue", linestyle='dotted')
axs[1, 0].plot(corr, lower_bound3_basket_ext,color="blue",linestyle='dashed')
axs[1, 0].plot(corr, upper_bound3_basket,color="red", linestyle='dotted')
axs[1, 0].plot(corr, upper_bound3_basket_ext,color="red",linestyle='dashed')
axs[1, 0].plot(corr, np.repeat(np.max(upper_bound3),N),color="black",linestyle='dashdot')
axs[1, 0].plot(corr, np.repeat(np.min(lower_bound3),N),color="black",linestyle='dashdot')
axs[1, 0].set_title(r'$c_6$')
axs[1, 0].set_xticks([-1,-0.5,0,0.5,1])
#axs[1, 0].set_yticks([0,0.5])
axs[1, 0].fill_between(corr, lower_bound3, lower_bound3_basket, color='aliceblue')
axs[1, 0].fill_between(corr, upper_bound3, upper_bound3_basket, color='mistyrose')
axs[1, 1].plot(corr, upper_bound4,color="red",label = "Correlations, Upper Bound")
axs[1, 1].plot(corr, upper_bound4_basket,color="red", linestyle='dotted',label = "Basket Prices, Avg. Upper Bound")
axs[1, 1].plot(corr, upper_bound4_basket_ext,color="red",linestyle='dashed',label = "Basket Prices, Min. Upper Bound")
axs[1, 1].plot(corr, lower_bound4_basket,color="blue", linestyle='dotted',label = "Basket Prices, Avg. Lower Bound")
axs[1, 1].plot(corr, lower_bound4_basket_ext,color="blue",linestyle='dashed',label = "Basket Prices, Max. Lower Bound")
axs[1, 1].plot(corr, lower_bound4,color="blue",label = "Correlations, Lower Bound")
axs[1, 1].plot(corr, np.repeat(np.max(upper_bound4),N),color="black",linestyle='dashdot',label = "Unconstrained Price Bounds")
axs[1, 1].plot(corr, np.repeat(np.min(lower_bound4),N),color="black",linestyle='dashdot')
axs[1, 1].set_title(r'$c_7$')
axs[1, 1].set_xticks([-1,-0.5,0,0.5,1])
#axs[1, 1].set_yticks([0.01,0.02])
axs[1, 1].fill_between(corr, lower_bound4, lower_bound4_basket, color='aliceblue')
axs[1, 1].fill_between(corr, upper_bound4, upper_bound4_basket, color='mistyrose')
axs[0, 0].set(ylabel='Price Bounds')
axs[1, 0].set(xlabel='Correlation', ylabel='Price Bounds')
axs[1, 1].set(xlabel='Correlation')
axs[0,0].grid(True, linestyle='--')
axs[0,1].grid(True, linestyle='--')
axs[1,0].grid(True, linestyle='--')
axs[1,1].grid(True, linestyle='--')

fig.tight_layout()
fig.subplots_adjust(right=1,wspace = 0.25)
plt.savefig('fig_correlations_improvement_loss_time2.eps', format='eps')
plt.show()

#plt.tight_layout()
